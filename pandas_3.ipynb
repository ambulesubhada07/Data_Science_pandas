# %% [markdown]
# <a href="https://colab.research.google.com/github/ambulesubhada07/Data_Science_pandas/blob/main/pandas_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **load dataset**

# %%
import pandas as pd

# %%
# from github: .csv .txt .tsv .data
import pandas as pd

f = pd.read_csv('https://raw.githubusercontent.com/hakimyameen/Datasets/refs/heads/main/fifa_eda.csv')
f.head(2)  # check first 2 records
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
#
#            Club     Value   Wage Preferred Foot  International Reputation  \
# 0  FC Barcelona  110500.0  565.0           Left                       5.0
# 1      Juventus   77000.0  405.0          Right                       5.0
#
#    Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 0          4.0       RF    2004           2021-01-01  5.583333   159.0
# 1          5.0       ST    2018           2022-01-01  6.166667   183.0
#
#    Release Clause
# 0        226500.0
# 1        127100.0

# %%
f.tail(3) # last 3 records
# Out:
#            ID            Name  Age Nationality  Overall  Potential  \
# 18204  241638       B. Worman   16     England       47         67
# 18205  246268  D. Walker-Rice   17     England       47         66
# 18206  246269       G. Nugent   16     England       46         66
#
#                    Club  Value  Wage Preferred Foot  International Reputation  \
# 18204  Cambridge United   60.0   1.0          Right                       1.0
# 18205   Tranmere Rovers   60.0   1.0          Right                       1.0
# 18206   Tranmere Rovers   60.0   1.0          Right                       1.0
#
#        Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 18204          2.0       ST    2017           2021-01-01  5.666667   148.0
# 18205          2.0       RW    2018           2019-01-01  5.833333   154.0
# 18206          2.0       CM    2018           2019-01-01  5.833333   176.0
#
#        Release Clause
# 18204           165.0
# 18205           143.0
# ...

# %%
f.sample(3)  # randomly select any 3 records
# Out:
#            ID            Name  Age   Nationality  Overall  Potential  \
# 17808  245123    A. Mahlonoko   16  South Africa       52         71
# 11927  207584        M. Boman   29        Sweden       64         64
# 7415   190408  M. Reginiussen   30        Norway       68         68
#
#                   Club  Value  Wage Preferred Foot  International Reputation  \
# 17808  Orlando Pirates  100.0   1.0          Right                       1.0
# 11927       Randers FC  450.0   4.0          Right                       1.0
# 7415   Ranheim Fotball  825.0   2.0          Right                       1.0
#
#        Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 17808          2.0      CAM    2018           2020-01-01  5.666667   130.0
# 11927          2.0       ST    2018           2019-01-01  6.166667   203.0
# 7415           3.0      LCM    2012           2019-01-01  5.750000   154.0
#
#        Release Clause
# 17808           278.0
# 11927           563.0
# ...

# %%
# download any excel csv txt file from github
# link: https://github.com/prasertcbs/basic-dataset/tree/master/Tokyo2020
dt = pd.read_excel('/content/Olympic2020_medal.xlsx')
dt.head(2)
# Out:
#                          Team  NOC  Gold  Silver  Bronze  Total
# 0    United States of America  USA    39      41      33    113
# 1  People's Republic of China  CHN    38      32      18     88

# %% [markdown]
# # **Perform Initial Operations**

# %%
# summary of dataset info()
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Nationality               18207 non-null  object
#  4   Overall                   18207 non-null  int64
#  5   Potential                 18207 non-null  int64
#  6   Club                      17966 non-null  object
#  7   Value                     17955 non-null  float64
#  8   Wage                      18207 non-null  float64
#  9   Preferred Foot            18207 non-null  object
#  10  International Reputation  18159 non-null  float64
#  11  Skill Moves               18159 non-null  float64
#  12  Position                  18207 non-null  object
# ...

# %%
f.shape
# Out:
# (18207, 18)

# %%
# check column names
f.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Wage', 'Preferred Foot', 'International Reputation',
#        'Skill Moves', 'Position', 'Joined', 'Contract Valid Until', 'Height',
#        'Weight', 'Release Clause'],
#       dtype='object')

# %%
f['Preferred Foot']
# Out:
# 0         Left
# 1        Right
# 2        Right
# 3        Right
# 4        Right
#          ...
# 18202    Right
# 18203    Right
# 18204    Right
# 18205    Right
# 18206    Right
# Name: Preferred Foot, Length: 18207, dtype: object

# %%
# check statistical summary of data
f.describe().T # will be applied on Numeric data
# Out:
#                             count           mean           std          min  \
# ID                        18207.0  214298.338606  29965.244204    16.000000
# Age                       18207.0      25.122206      4.669943    16.000000
# Overall                   18207.0      66.238699      6.908930    46.000000
# Potential                 18207.0      71.307299      6.136496    48.000000
# Value                     17955.0    2444.530214   5626.715434    10.000000
# Wage                      18207.0       9.731312     21.999290     0.000000
# International Reputation  18159.0       1.113222      0.394031     1.000000
# Skill Moves               18159.0       2.361308      0.756164     1.000000
# Joined                    18207.0    2016.420607      2.018194  1991.000000
# Height                    18207.0       5.946771      0.220514     5.083333
# Weight                    18207.0     165.979129     15.572775   110.000000
# ...

# %%
f.describe().style.background_gradient('Spectral')
# Out:
# <style type="text/css">
# #T_cc71d_row0_col0 {
#   background-color: #c52c4b;
#   color: #f1f1f1;
# }
# #T_cc71d_row0_col1, #T_cc71d_row0_col2, #T_cc71d_row0_col3, #T_cc71d_row0_col5, #T_cc71d_row0_col6, #T_cc71d_row0_col7, #T_cc71d_row0_col8, #T_cc71d_row0_col9, #T_cc71d_row0_col10, #T_cc71d_row7_col0, #T_cc71d_row7_col4, #T_cc71d_row7_col11 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_cc71d_row0_col4 {
#   background-color: #e45549;
#   color: #f1f1f1;
# }
# #T_cc71d_row0_col11 {
#   background-color: #c9314c;
#   color: #f1f1f1;
# }
# #T_cc71d_row1_col0 {
#   background-color: #4199b6;
#   color: #f1f1f1;
# }
# ...

# %%
# describe on categorical data
f.describe(include='object').T
# Out:
#                       count unique           top   freq
# Name                  18207  17194  J. Rodríguez     11
# Nationality           18207    164       England   1662
# Club                  17966    651      RC Celta     33
# Preferred Foot        18207      2         Right  13996
# Position              18207     27            ST   2154
# Contract Valid Until  17918     35    2019-01-01   4870

# %%
f['Preferred Foot'].value_counts()
# Out:
# Preferred Foot
# Right    13996
# Left      4211
# Name: count, dtype: int64

# %%
f['Position'].value_counts()
# Out:
# Position
# ST     2154
# GK     2027
# CB     1779
# CM     1395
# LB     1372
# RB     1291
# RM     1127
# LM     1095
# CAM     959
# CDM     948
# RCB     662
# LCB     648
# LCM     395
# RCM     391
# LW      381
# RW      370
# RDM     248
# LDM     243
# LS      207
# RS      203
# RWB      87
# LWB      78
# CF       74
# LAM      21
# RAM      21
# RF       16
# LF       15
# Name: count, dtype: int64

# %%
# display/check data types of all columns
f.dtypes
# Out:
# ID                            int64
# Name                         object
# Age                           int64
# Nationality                  object
# Overall                       int64
# Potential                     int64
# Club                         object
# Value                       float64
# Wage                        float64
# Preferred Foot               object
# International Reputation    float64
# Skill Moves                 float64
# Position                     object
# Joined                        int64
# Contract Valid Until         object
# Height                      float64
# Weight                      float64
# Release Clause              float64
# dtype: object

# %%
# select columns with numeric data type
f.select_dtypes(include='number')  # int float object
# Out:
#            ID  Age  Overall  Potential     Value   Wage  \
# 0      158023   31       94         94  110500.0  565.0
# 1       20801   33       94         94   77000.0  405.0
# 2      190871   26       92         93  118500.0  290.0
# 3      193080   27       91         93   72000.0  260.0
# 4      192985   27       91         92  102000.0  355.0
# ...       ...  ...      ...        ...       ...    ...
# 18202  238813   19       47         65      60.0    1.0
# 18203  243165   19       47         63      60.0    1.0
# 18204  241638   16       47         67      60.0    1.0
# 18205  246268   17       47         66      60.0    1.0
# 18206  246269   16       46         66      60.0    1.0
#
#        International Reputation  Skill Moves  Joined    Height  Weight  \
# 0                           5.0          4.0    2004  5.583333   159.0
# 1                           5.0          5.0    2018  6.166667   183.0
# 2                           5.0          5.0    2017  5.750000   150.0
# ...

# %%
# rename the column name
# rename Contract Valid Until to Contract
#f.rename({0:'A'})  # default it rename row at the place of 0 --> 'A'
f.rename(columns={'Contract Valid Until':'Contract'},inplace=True) # inplace will make the permnt chnages

# %%
# check updated name
f.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Wage', 'Preferred Foot', 'International Reputation',
#        'Skill Moves', 'Position', 'Joined', 'Contract', 'Height', 'Weight',
#        'Release Clause'],
#       dtype='object')

# %%
f.rename({0:'A'})
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# A      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
# Assignment: rename below columns
# Preferred Foot--> Preferred_Foot
# International Reputation --> International_Reputation
# Release Clause--> Release_Clause

# %%
col = f.columns
print([c.replace(' ','_') for c in col])
# replace directly in columns
f.columns = [c.replace(' ','_') for c in col] #list comprehance
# Out:
# ['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value', 'Wage', 'Preferred_Foot', 'International_Reputation', 'Skill_Moves', 'Position', 'Joined', 'Contract', 'Height', 'Weight', 'Release_Clause']

# %%
f.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Wage', 'Preferred_Foot', 'International_Reputation',
#        'Skill_Moves', 'Position', 'Joined', 'Contract', 'Height', 'Weight',
#        'Release_Clause'],
#       dtype='object')

# %%
# create a dataframe with number data in str
k = ['34000','50000','70000']
sal = pd.DataFrame(k,columns=['salary'])
sal
# Out:
#   salary
# 0  34000
# 1  50000
# 2  70000

# %%
sal.dtypes
# Out:
# salary    object
# dtype: object

# %%
#convert salary column data type to float
sal['salary'] = sal['salary'].astype('float32')

# %%
sal
# Out:
#     salary
# 0  34000.0
# 1  50000.0
# 2  70000.0

# %% [markdown]
# # **Start performing some analysis**
